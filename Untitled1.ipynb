# %%
import pandas as pd

# %%
train_data = pd.read_csv('train.csv')
train_data
# Out:
#              id  week  ...  homepage_featured  num_orders
# 0       1379560     1  ...                  0         177
# 1       1466964     1  ...                  0         270
# 2       1346989     1  ...                  0         189
# 3       1338232     1  ...                  0          54
# 4       1448490     1  ...                  0          40
# ...         ...   ...  ...                ...         ...
# 456543  1271326   145  ...                  0          68
# 456544  1062036   145  ...                  0          42
# 456545  1110849   145  ...                  0         501
# 456546  1147725   145  ...                  0         729
# 456547  1361984   145  ...                  0         162
#
# [456548 rows x 9 columns]

# %%
x = train_data.iloc[:,2:8]
x
# Out:
#         center_id  meal_id  ...  emailer_for_promotion  homepage_featured
# 0              55     1885  ...                      0                  0
# 1              55     1993  ...                      0                  0
# 2              55     2539  ...                      0                  0
# 3              55     2139  ...                      0                  0
# 4              55     2631  ...                      0                  0
# ...           ...      ...  ...                    ...                ...
# 456543         61     1543  ...                      0                  0
# 456544         61     2304  ...                      0                  0
# 456545         61     2664  ...                      0                  0
# 456546         61     2569  ...                      0                  0
# 456547         61     2490  ...                      0                  0
#
# [456548 rows x 6 columns]

# %%
y = train_data.iloc[:,8]
y
# Out:
# 0         177
# 1         270
# 2         189
# 3          54
# 4          40
#          ...
# 456543     68
# 456544     42
# 456545    501
# 456546    729
# 456547    162
# Name: num_orders, Length: 456548, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
Rfr = RandomForestRegressor()
Rfr.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
test_data = pd.read_csv('test.csv')
test_data
# Out:
#             id  week  ...  emailer_for_promotion  homepage_featured
# 0      1028232   146  ...                      0                  0
# 1      1127204   146  ...                      0                  0
# 2      1212707   146  ...                      0                  0
# 3      1082698   146  ...                      0                  0
# 4      1400926   146  ...                      0                  0
# ...        ...   ...  ...                    ...                ...
# 32568  1250239   155  ...                      0                  0
# 32569  1039516   155  ...                      0                  0
# 32570  1158107   155  ...                      0                  0
# 32571  1444235   155  ...                      0                  0
# 32572  1291286   155  ...                      0                  0
#
# [32573 rows x 8 columns]

# %%
x_p = test_data.iloc[:,2:8]
x_p
# Out:
#        center_id  meal_id  ...  emailer_for_promotion  homepage_featured
# 0             55     1885  ...                      0                  0
# 1             55     1993  ...                      0                  0
# 2             55     2539  ...                      0                  0
# 3             55     2631  ...                      0                  0
# 4             55     1248  ...                      0                  0
# ...          ...      ...  ...                    ...                ...
# 32568         61     1543  ...                      0                  0
# 32569         61     2304  ...                      0                  0
# 32570         61     2664  ...                      0                  0
# 32571         61     2569  ...                      0                  0
# 32572         61     2490  ...                      0                  0
#
# [32573 rows x 6 columns]

# %%
pred = pd.DataFrame(Rfr.predict(x_p))
pred
# Out:
#                 0
# 0      352.545000
# 1      154.800000
# 2      185.937500
# 3       73.240000
# 4       58.879690
# ...           ...
# 32568   76.963167
# 32569   18.573512
# 32570  284.210000
# 32571  241.369667
# 32572  205.755000
#
# [32573 rows x 1 columns]

# %%
test_data['id'] = test_data['id'].to_csv('submission.csv')

# %%
sub = pd.read_csv('submission.csv')
sub
# Out:
#        Unnamed: 0       id
# 0               0  1028232
# 1               1  1127204
# 2               2  1212707
# 3               3  1082698
# 4               4  1400926
# ...           ...      ...
# 32568       32568  1250239
# 32569       32569  1039516
# 32570       32570  1158107
# 32571       32571  1444235
# 32572       32572  1291286
#
# [32573 rows x 2 columns]

# %%
sub['num_orders'] = pred

# %%
sub = sub.to_csv('final_sub.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-aab3e2491849> in <module>()
# ----> 1 sub = sub.to_csv('final_sub.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
pd.read_csv('finalsub.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-64de0f55d098> in <module>()
# ----> 1 pd.read_csv('finalsub.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...
